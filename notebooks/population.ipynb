# %% [markdown]
# # Process and merge population files

# %%
# import argparse
import re
import sys
import os
from pathlib import Path

import pandas as pd

# %%
def rename_period_columns(df: pd.DataFrame) -> pd.DataFrame:
    """
    Rename data columns to their extracted period and sum columns that
    share the same period label.  Non-data columns are kept as-is.
    """
    id_cols = ["organisationunitid", "organisationunitname", "organisationunitcode"]
    rename_map: dict[str, str] = {}
    no_period: list[str] = []

    for col in df.columns:
        if col in id_cols:
            continue
        period = " ".join(col.split()[-2:])
        if period:
            rename_map[col] = period
        else:
            no_period.append(col)

    if no_period:
        print(
            f"[warning] Could not extract a period from {len(no_period)} column(s); "
            f"they will be dropped:\n  " + "\n  ".join(no_period)
        )

    # Keep only id cols + mappable cols
    keep_cols = id_cols + list(rename_map.keys())
    df = df[keep_cols].rename(columns=rename_map)
    
    remaining_items = [item for item in list(df.columns) if item not in set(id_cols)]
    new_list = id_cols + remaining_items
    result = df[new_list]

    return result

# %%
df = pd.read_csv('../raw_data/population.csv')
df.pop("organisationunitdescription")
# Out:
# 0      à¤«à¤•à¥�à¤¤à¤¾à¤™à¥�à¤²à¥�à¤™à¥�à¤— à¤—à¤¾à¤‰...
# 1      à¤®à¤¿à¤•à¥�à¤µà¤¾à¤–à¥‹à¤²à¤¾ à¤—à¤¾à¤‰à¤�à¤ª...
# 2      à¤®à¥‡à¤°à¤¿à¤™à¥�à¤—à¤¦à¥‡à¤¨ à¤—à¤¾à¤‰à¤�à¤ª...
# 3      à¤®à¥ˆà¤µà¤¾à¤–à¥‹à¤²à¤¾ à¤—à¤¾à¤‰à¤�à¤ªà¤¾à¤²...
# 4      à¤†à¤ à¤°à¤¾à¤ˆ à¤¤à¥�à¤°à¤¿à¤µà¥‡à¤£à¥€ à¤—à¤...
#                              ...
# 748    à¤®à¤¾à¤¹à¤¾à¤•à¤¾à¤²à¥€ à¤¨à¤—à¤°à¤ªà¤¾à¤²à¤¿...
# 749    à¤²à¤¾à¤²à¤�à¤¾à¤¡à¥€ à¤—à¤¾à¤‰à¤�à¤ªà¤¾à¤²à¤¿...
# 750    à¤ªà¥�à¤¨à¤°à¥�à¤µà¤¾à¤¸ à¤¨à¤—à¤°à¤ªà¤¾à¤²à¤¿...
# 751       à¤¬à¥‡à¤²à¥Œà¤°à¥€ à¤¨à¤—à¤°à¤ªà¤¾à¤²à¤¿à¤•à¤¾
# 752    à¤¬à¥‡à¤²à¤¡à¤¾à¤�à¤¡à¥€ à¤—à¤¾à¤‰à¤�à¤ªà¤¾à¤²...
# Name: organisationunitdescription, Length: 753, dtype: str

# %%
# ---- Collapse period columns per level independently --------------------
print("Extracting and collapsing period columns...")
df_raw = rename_period_columns(df)

period_cols = [c for c in df_raw.columns if c not in ["organisationunitid", "organisationunitname", "organisationunitcode"]]
print(f"  {len(period_cols)} unique period(s) found: {', '.join(period_cols[:5])}" + "...")
# Out:
# Extracting and collapsing period columns...
#   96 unique period(s) found: March 2024, February 2025, September 2022, March 2021, September 2019...

# %%
df_raw.columns = pd.to_datetime(df_raw.columns, format='%B %Y', errors = "coerce")

# %%
df_raw.head(3)
# Out:
#            NaT                                   NaT    NaT  2024-03-01  \
# 0  TnT6m8FZEet  10101 Phaktanlung Rural Municipality  10101       11197
# 1  gIhVZulvEsV   10102 Mikwakhola Rural Municipality  10102        7628
# 2  dcsJaeSXHa6    10103 Meringden Rural Municipality  10103       11198
#
#    2025-02-01  2022-09-01  2021-03-01  2019-09-01  2022-02-01  2020-11-01  \
# 0       11197       11951       11928       12283       11951       12305
# 1        7628        8023        7995        9324        8023        9329
# 2       11198       12086       12046       13743       12086       13789
#
#    ...  2024-11-01  2023-09-01  2019-07-01  2024-04-01  2021-11-01  \
# 0  ...       11197       11197       12283       11197       11928
# 1  ...        7628        7628        9324        7628        7995
# 2  ...       11198       11198       13743       11198       12046
#
#    2020-12-01  2023-02-01  2025-06-01  2023-08-01  2025-01-01
# 0       12305       11197       11197       11197       11197
# 1        9329        7628        7628        7628        7628
# 2       13789       11198       11198       11198       11198
#
# [3 rows x 99 columns]

# %%
time_cols = [c for c in df_raw.columns if c not in ["organisationunitid", "organisationunitname", "organisationunitcode"]]
df_time = df_raw[time_cols].T.reset_index().resample("YE", on="index").mean().T.reset_index(drop=True)

# %%
df_clean = pd.concat([df[["organisationunitid", "organisationunitname", "organisationunitcode"]], df_time], axis = 1)

# %%
df_clean
# Out:
#     organisationunitid                       organisationunitname  \
# 0          TnT6m8FZEet       10101 Phaktanlung Rural Municipality
# 1          gIhVZulvEsV        10102 Mikwakhola Rural Municipality
# 2          dcsJaeSXHa6         10103 Meringden Rural Municipality
# 3          zce1OaOO6G0        10104 Maiwakhola Rural Municipality
# 4          zGGY6Sw9Uuw  10105 Aatharai Tribeni Rural Municipality
# ..                 ...                                        ...
# 748        Vaz2akuQgf5         70905 Dodharachadani  Municipality
# 749        NXKDqdR7CUd          70906 Laljhadi Rural Municipality
# 750        uyEaMlGY93o                70907 Punarbas Municipality
# 751        xTWW1v7S7qX                 70908 Belouri Municipality
# 752        MidYQV1Jxnv          70909 Beldandi Rural Municipality
#
#      organisationunitcode 2018-12-31 00:00:00 2019-12-31 00:00:00  \
# 0                   10101             12261.0             12283.0
# 1                   10102              9311.0              9324.0
# 2                   10103             13705.0             13743.0
# 3                   10104             11262.0             11272.0
# 4                   10105             14041.0             14065.0
# ..                    ...                 ...                 ...
# 748                 70905             44765.0             45539.0
# 749                 70906             25882.0             26330.0
# 750                 70907             61003.0             62020.0
# 751                 70908             61291.0             62345.0
# 752                 70909             24812.0             25211.0
#
#     2020-12-31 00:00:00 2021-12-31 00:00:00 2022-12-31 00:00:00  \
# 0               12305.0             11928.0             11951.0
# 1                9329.0              7995.0              8023.0
# 2               13789.0             12046.0             12086.0
# 3               11288.0             10370.0             10395.0
# 4               14089.0             12289.0             12298.0
# ..                  ...                 ...                 ...
# 748             46309.0             43596.0             44311.0
# 749             26786.0             25337.0             25757.0
# 750             63055.0             61785.0             62787.0
# 751             63412.0             54048.0             54869.0
# 752             25616.0             24962.0             24648.0
#
#     2023-12-31 00:00:00 2024-12-31 00:00:00 2025-12-31 00:00:00
# 0               11197.0             11197.0             11197.0
# 1                7628.0              7628.0              7628.0
# 2               11198.0             11198.0             11198.0
# 3                9730.0              9730.0              9730.0
# 4               11665.0             11665.0             11665.0
# ..                  ...                 ...                 ...
# 748             43645.0             43645.0             43645.0
# 749             23686.0             23686.0             23686.0
# 750             63262.0             63262.0             63262.0
# 751             54456.0             54456.0             54456.0
# 752             20962.0             20962.0             20962.0
#
# [753 rows x 11 columns]

# %%
df_clean[df_clean["organisationunitname"].astype(str).str.contains('Sani', na=False)]
# Out:
#     organisationunitid                organisationunitname  \
# 641        lfvPvTzR3Kt  60802 Sanibheri Rural Municipality
#
#      organisationunitcode 2018-12-31 00:00:00 2019-12-31 00:00:00  \
# 641                 60802             23722.0             23939.0
#
#     2020-12-31 00:00:00 2021-12-31 00:00:00 2022-12-31 00:00:00  \
# 641             24160.0             24822.0             25143.0
#
#     2023-12-31 00:00:00 2024-12-31 00:00:00 2025-12-31 00:00:00
# 641             25576.0             25576.0             25576.0

# %%
df_clean['district_code'] = df_clean["organisationunitcode"].astype(str).str[:3]

# %%
df_dists = df_clean.groupby(["district_code"]).sum().reset_index().drop(columns=["organisationunitid", "organisationunitname", "organisationunitcode"])

# %%
df_dists.head(4)
# Out:
#   district_code 2018-12-31 00:00:00 2019-12-31 00:00:00 2020-12-31 00:00:00  \
# 0           101            130395.0            130649.0            130890.0
# 1           102            156583.0            156064.0            155531.0
# 2           103            103060.0            102517.0            101969.0
# 3           104            151153.0            151414.0            151657.0
#
#   2021-12-31 00:00:00 2022-12-31 00:00:00 2023-12-31 00:00:00  \
# 0            120366.0            120455.0            114187.0
# 1            159468.0            161292.0            154839.0
# 2            104720.0            105343.0            102606.0
# 3            140989.0            141505.0            134442.0
#
#   2024-12-31 00:00:00 2025-12-31 00:00:00
# 0            114187.0            114187.0
# 1            154839.0            154839.0
# 2            102606.0            102606.0
# 3            134442.0            134442.0

# %%
df_clean.to_csv("../proc_data/pop_muni.csv", index=False)
df_dists.to_csv("../proc_data/pop_dist.csv", index=False)

print(f"\nSaved:")
print(f"  {"pop_muni.csv"}")
print(f"  {"pop_dist.csv"}")
print("Done.")
# Out:
# Saved:
#   pop_muni.csv
#   pop_dist.csv
# Done.

# %%
dist_df = pd.read_csv('../proc_data/districts.csv', parse_dates=["month"], dtype={"organisationunitcode": str})
dist_df['year'] = dist_df['month'].dt.year
dist_df.head(5)
# Out:
#   organisationunitid organisationunitname             province_name  \
# 0        DLyaDAF00hm        204 MAHOTTARI        2 Madhesh Province
# 1        vjL1uSC10Jh           701 BAJURA  7 Sudurpashchim Province
# 2        CNFRaFUfLjo            111 JHAPA          1 Koshi Province
# 3        Fh294RrB7an            208 PARSA        2 Madhesh Province
# 4        uHEl9oRZm8L    102 SANKHUWASABHA          1 Koshi Province
#
#    province_code organisationunitcode      month  p_cases  np_cases  year
# 0              2                  204 2024-11-27      2.0       1.0  2024
# 1              7                  701 2024-11-27      0.0       0.0  2024
# 2              1                  111 2024-11-27      0.0      14.0  2024
# 3              2                  208 2024-11-27      1.0       2.0  2024
# 4              1                  102 2024-11-27      7.0       7.0  2024

# %%
dist_pop_long = pd.melt(df_dists,
        id_vars=['district_code'],
        var_name="year",
        value_name="population")
dist_pop_long['year'] = pd.to_datetime(dist_pop_long['year']).dt.year

dist_pop_long.head(3)
# Out:
#   district_code  year population
# 0           101  2018   130395.0
# 1           102  2018   156583.0
# 2           103  2018   103060.0

# %%
dist_pop_merged = dist_df.merge(
    dist_pop_long,
    left_on=["organisationunitcode", "year"],
    right_on=["district_code", "year"],
    how='left'
).drop(columns=["district_code"])

# %%
dist_pop_merged['population'] = (
    dist_pop_merged
        .sort_values('year')
        .groupby('organisationunitcode')['population']
        .transform(lambda s: s.bfill())
)

# %%
dist_pop_merged.sort_values(by='month')
# Out:
#      organisationunitid organisationunitname             province_name  \
# 4927        NSLL7YIXBJH          704 BAITADI  7 Sudurpashchim Province
# 4905        U8Rk7sYzFmK    302 SINDHUPALCHOK        3 Bagmati Province
# 4904        uyGkoQ4F9rT       705 DADELDHURA  7 Sudurpashchim Province
# 4903        Wep3D4POB3H       103 SOLUKHUMBU          1 Koshi Province
# 4902        eW2b8SUYRWt         107 DHANKUTA          1 Koshi Province
# ...                 ...                  ...                       ...
# 3059        Yacp1fLlWut           402 MANANG        4 Gandaki Province
# 3060        ewPc6zXy53n            603 HUMLA        6 Karnali Province
# 3061        HL5fSUsp2vJ           609 SALYAN        6 Karnali Province
# 3054        eW2b8SUYRWt         107 DHANKUTA          1 Koshi Province
# 3041        BITtrV4c0xf       608 RUKUM WEST        6 Karnali Province
#
#       province_code organisationunitcode      month  p_cases  np_cases  year  \
# 4927              7                  704 2015-04-25      0.0       0.0  2015
# 4905              3                  302 2015-04-25      0.0       0.0  2015
# 4904              7                  705 2015-04-25      1.0       4.0  2015
# 4903              1                  103 2015-04-25      0.0       0.0  2015
# 4902              1                  107 2015-04-25      0.0       1.0  2015
# ...             ...                  ...        ...      ...       ...   ...
# 3059              4                  402 2025-11-28      0.0       0.0  2025
# 3060              6                  603 2025-11-28      0.0       0.0  2025
# 3061              6                  609 2025-11-28      0.0       0.0  2025
# 3054              1                  107 2025-11-28      0.0       0.0  2025
# 3041              6                  608 2025-11-28      0.0       1.0  2025
#
#      population
# 4927   264114.0
# 4905   293665.0
# 4904   155955.0
# 4903   103060.0
# 4902   170068.0
# ...         ...
# 3059     4690.0
# 3060    56140.0
# 3061   235463.0
# 3054   147906.0
# 3041   171844.0
#
# [9856 rows x 10 columns]

# %%
proc_data_folder = "../proc_data"
out_district = "districts.csv"

dist_pop_merged.to_csv(os.path.join(proc_data_folder, out_district), index=False)

print(f"\nSaved:")
print(f"  {out_district}")
print("Done.")
# Out:
# Saved:
#   districts.csv
# Done.
